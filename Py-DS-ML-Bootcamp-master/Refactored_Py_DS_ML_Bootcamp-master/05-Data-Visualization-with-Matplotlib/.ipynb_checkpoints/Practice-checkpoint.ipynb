# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# FUNCTIONAL
plt.plot(x,y)

# %%
# FUNCTIONAL (if not jupyter notebook)
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,"r-")

# %%
plt.plot(x,y)
plt.xlabel("x Label")
plt.ylabel("Y Label")
plt.title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,"r")

plt.subplot(1,2,2)
plt.plot(y,x,"b")

# %%
# OO
fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(x,y)
axes.set_xlabel("X Label")
axes.set_ylabel("Y Label")
axes.set_title("Set Title")
# Out:
# Text(0.5, 1.0, 'Set Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y)
axes1.set_title("LARGER PLOT")

axes2.plot(y,x)
axes2.set_title("SMALLER PLOT")
# Out:
# Text(0.5, 1.0, 'SMALLER PLOT')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.5,0.15,0.4,0.3])

# %%
fig = plt.figure()

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes1.plot(x,y)

# %%
fig,axes = plt.subplots()

axes.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

#axes.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=3,ncols=3)

#axes.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=3,ncols=3)

#axes.plot(x,y)
plt.tight_layout()

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

#axes.plot(x,y)
plt.tight_layout()

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000019FB8FC4988>,
# ...
#       dtype=object)

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

for current_ax in axes:
    current_ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

axes[0].plot(x,y)
axes[0].set_title("First Plot")

axes[1].plot(y,x)
axes[1].set_title("Second Plot")

plt.tight_layout()

# %%
fig = plt.figure(figsize=(3,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig = plt.figure(figsize=(8,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig = plt.figure(figsize=(3,2),dpi=100)

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=2,ncols=1,figsize=(8,2))

axes[0].plot(x,y)

axes[1].plot(y,x)

plt.tight_layout()

# %%
fig.savefig("my_picture.png")

# %%
fig.savefig("my_picture.jpg",dpi=200)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

ax.set_title("Title")
ax.set_ylabel("Y")
ax.set_xlabel("X")
# Out:
# Text(0.5, 0, 'X')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

ax.plot(y,x)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label="X Sauared")
ax.plot(x,x**3,label="X Cubed")

ax.legend()

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label="X Sauared")
ax.plot(x,x**3,label="X Cubed")

ax.legend(loc=1)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label="X Sauared")
ax.plot(x,x**3,label="X Cubed")

ax.legend(loc=10)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label="X Sauared")
ax.plot(x,x**3,label="X Cubed")

ax.legend(loc=(0.1,0.1))

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color="blue")

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color="orange")

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color="green")

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color="#FFE5CC") #RGB Hex Code

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color="purple", linewidth=1)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color="purple", linewidth=20)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color="purple", linewidth=0.1)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color="purple", linewidth=3, alpha=0.1)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color="purple", linewidth=3, alpha=1)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color="purple", lw=3, alpha=1)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color="purple", lw=3, linestyle="--")

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color="purple", lw=3, linestyle="-.")

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color="purple", lw=3, linestyle=":")

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color="purple", lw=3, linestyle="steps")
# Out:
# C:\Users\okuyama\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Passing the drawstyle with the linestyle as a single string is deprecated since Matplotlib 3.1 and support will be removed in 3.3; please pass the drawstyle separately using the drawstyle keyword argument to Line2D or set_drawstyle() method (or ds/set_ds()).
#   """

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color="purple", lw=3, linestyle="-")

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color="purple", lw=3, ls="-")

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
len(x)
# Out:
# 11

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color="purple", lw=3, ls="-", marker="o")

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color="purple", lw=3, ls="-", marker="+")

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color="purple", lw=0.5, ls="-", marker="*")

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color="purple", lw=0.5, ls="-", marker="1")

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color="purple", lw=1, ls="-", marker="+", markersize=1)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color="purple", lw=1, ls="-", marker="+", markersize=20)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color="purple", lw=1, ls="-", marker="o", markersize=20)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color="purple", lw=1, ls="-", marker="o", markersize=20,markerfacecolor="yellow")

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color="purple", lw=1, ls="-", marker="o", markersize=20,markerfacecolor="yellow",markeredgewidth=5)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color="purple", lw=1, ls="-", marker="o", markersize=20,markerfacecolor="yellow",markeredgewidth=5,markeredgecolor="green")

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color="purple", lw=2, ls="--")

ax.set_xlim([0,1])
# Out:
# (0, 1)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color="purple", lw=2, ls="--")

ax.set_xlim([0,1])
ax.set_ylim([0,2])
# Out:
# (0, 2)

# %%
#loria.fr is a nice link

# %%
fig,ax = plt.subplots(figsize=(12,6))

ax.plot(x,x+1,color="red",linewidth=0.25)
ax.plot(x,x+2,color="red",linewidth=0.50)
ax.plot(x,x+3,color="red",linewidth=1.00)
ax.plot(x,x+4,color="red",linewidth=2.00)

# possible linestype options "-", "-", "-.",":","steps"
ax.plot(x,x+5,color="green",lw=3,linestyle="-")
ax.plot(x,x+6,color="green",lw=3,ls="-.")
ax.plot(x,x+7,color="green",lw=3,ls=":")

# custom dash
line,= ax.plot(x,x+8,color="black",lw=1.50)
line.set_dashes([5,10,15,10]) # format: line length, space length, ...

# possible marker symbols: marker = "+", "o", "*", "s", ",",".","1","2","3","4",...
ax.plot(x,x+9,color="blue",lw=3,ls="-",marker="+")
ax.plot(x,x+10,color="blue",lw=3,ls="--",marker="o")
ax.plot(x,x+11,color="blue",lw=3,ls="-",marker="s")
ax.plot(x,x+12,color="blue",lw=1,ls="--",marker=3)

# marker size and color
ax.plot(x,x+13,color="purple",lw=1,ls="-",marker="o",markersize=2)
ax.plot(x,x+14,color="purple",lw=1,ls="-",marker="o",markersize=4)
ax.plot(x,x+15,color="purple",lw=1,ls="-",marker="o",markersize=8,markerfacecolor="red")
ax.plot(x,x+16,color="purple",lw=1,ls="-",marker="s",markersize=8,
       markerfacecolor="yellow",markeredgewidth=3,markeredgecolor="green")
